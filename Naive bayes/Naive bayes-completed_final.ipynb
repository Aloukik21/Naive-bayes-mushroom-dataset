# %% [markdown]
# # Naive Bayes

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
data = pd.read_csv('mushrooms.csv')

# %% [markdown]
# ## Defining accuracy function

# %%
correct = 0
def accuracy(a,b):
    correct = 0
    for i in range(len(a)):
        if(a[i] == b[i]):
              correct = correct+1

    accu = correct/len(a) * 100
    print("Accuracy is", + accu)

# %% [markdown]
# ## Defining sensitivity function

# %%
def Sensitivity():

    sensi = (TP / (TP+FN))*100
    print("Sensitivity is", + sensi)

# %% [markdown]
# ## Defining specificity function

# %%
def Specificity():
    speci  = (TN/(TN + FP))*100
    print("Specificity is", + speci)

# %%
data
# Out:
#      cap_shape Cap_surface    bruises   category
# 0       Convex      Smooth    Bruises  Poisonous
# 1       Convex      Smooth    Bruises     Edible
# 2         Bell      Smooth    Bruises     Edible
# 3       Convex       Scaly    Bruises  Poisonous
# 4       Convex      Smooth  NoBruises     Edible
# ...        ...         ...        ...        ...
# 8119   Knobbed      Smooth  NoBruises     Edible
# 8120    Convex      Smooth  NoBruises     Edible
# 8121      Flat      Smooth  NoBruises     Edible
# 8122   Knobbed       Scaly  NoBruises  Poisonous
# 8123    Convex      Smooth  NoBruises     Edible
#
# [8124 rows x 4 columns]

# %%
y = data.category
X = data
#X = data.drop('category', axis=1)
#X=X[1:200]
#y=y[1:100]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3)

print(y_train.shape)
# Out:
# (5686,)

# %% [markdown]
# ## The warning can be ignored, beacuse wheneever dataset changes, it shows warning. IN the end dataset will be complete

# %%
y_train.replace({'Poisonous': 'Negative', 'Edible' : 'Positive'}, inplace = True)#------------replacing values of binary classes
y_test.replace({'Poisonous': 'Negative', 'Edible' : 'Positive'}, inplace = True)
X_train['category'].replace({'Poisonous': 'Negative', 'Edible' : 'Positive'}, inplace = True)#------------replacing values of binary classes
X_test['category'].replace({'Poisonous': 'Negative', 'Edible' : 'Positive'}, inplace = True)
# Out:
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py:6786: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %% [markdown]
# ## Defining probability function using m-estimate

# %%
def probability(a,b,m):#-------------defininf probility function with m-estimate
    
    p=(1/2)
    k = ((a+(m*p))/(b+m))
    return k

# %%
y_train[1:10]
# Out:
# 2786    Positive
# 3313    Negative
# 4012    Positive
# 4866    Negative
# 3923    Positive
# 4505    Negative
# 8004    Negative
# 2168    Positive
# 7690    Negative
# Name: category, dtype: object

# %%
print(y_train[y_train == 'Positive'].shape[0])
print(y_train[y_train == 'Negative'].shape[0])
# Out:
# 2946
# 2740

# %%
X_train[X_train.bruises == 'Bruises'][X_train.Cap_surface== 'Smooth']
# Out:
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      cap_shape Cap_surface  bruises  category
# 2388    Convex      Smooth  Bruises  Negative
# 5426    Convex      Smooth  Bruises  Negative
# 5348    Convex      Smooth  Bruises  Negative
# 728       Bell      Smooth  Bruises  Positive
# 5741   Knobbed      Smooth  Bruises  Positive
# ...        ...         ...      ...       ...
# 191     Convex      Smooth  Bruises  Positive
# 495       Bell      Smooth  Bruises  Positive
# 5392   Knobbed      Smooth  Bruises  Positive
# 5381    Convex      Smooth  Bruises  Negative
# 5564    Convex      Smooth  Bruises  Negative
#
# [616 rows x 4 columns]

# %% [markdown]
# ## Initial probabillity of dataset(class)

# %%
#--probability of positive and negative

Prob_positive = probability(X_train[X_train.category == 'Positive'].shape[0],X_train.shape[0],2)
Prob_negative = probability(X_train[X_train.category == 'Negative'].shape[0],X_train.shape[0],2)
print(Prob_positive)
print(Prob_negative)
# Out:
# 0.5181082981715893
# 0.4818917018284107

# %%
print(X_train.cap_shape.unique())#------------getting unique values of each feature
print(X_train.Cap_surface.unique())
print(X_train.bruises.unique())
# Out:
# ['Convex' 'Flat' 'Knobbed' 'Bell' 'Sunken' 'Conical']
# ['Smooth' 'Fiberous' 'Scaly' 'Grooves']
# ['Bruises' 'NoBruises']

# %%
#---------starting for feature 1 (cap_shape)
Prob_convex_pos = probability(X_train[X_train.cap_shape == 'Convex'][X_train.category == 'Positive'].shape[0],X_train[y_train == 'Positive'].shape[0],6)
Prob_convex_neg = probability(X_train[X_train.cap_shape == 'Convex'][X_train.category == 'Negative'].shape[0],X_train[y_train == 'Negative'].shape[0],6)


Prob_Conical_pos = probability(X_train[X_train.cap_shape == 'Conical'][X_train.category == 'Positive'].shape[0],X_train[y_train == 'Positive'].shape[0],6)
Prob_Conical_neg = probability(X_train[X_train.cap_shape == 'Conical'][X_train.category == 'Negative'].shape[0],X_train[y_train == 'Negative'].shape[0],6)


Prob_Bell_pos = probability(X_train[X_train.cap_shape == 'Bell'][X_train.category == 'Positive'].shape[0],X_train[y_train == 'Positive'].shape[0],6)
Prob_Bell_neg = probability(X_train[X_train.cap_shape == 'Bell'][X_train.category == 'Negative'].shape[0],X_train[y_train == 'Negative'].shape[0],6)

Prob_Flat_pos = probability(X_train[X_train.cap_shape == 'Flat'][X_train.category == 'Positive'].shape[0],X_train[y_train == 'Positive'].shape[0],6)
Prob_Flat_neg = probability(X_train[X_train.cap_shape == 'Flat'][X_train.category == 'Negative'].shape[0],X_train[y_train == 'Negative'].shape[0],6)


Prob_Knobbed_pos = probability(X_train[X_train.cap_shape == 'Knobbed'][X_train.category == 'Positive'].shape[0],X_train[y_train == 'Positive'].shape[0],6)
Prob_Knobbed_neg = probability(X_train[X_train.cap_shape == 'Knobbed'][X_train.category == 'Negative'].shape[0],X_train[y_train == 'Negative'].shape[0],6)

Prob_Sunken_pos = probability(X_train[X_train.cap_shape == 'Sunken'][X_train.category == 'Positive'].shape[0],X_train[y_train == 'Positive'].shape[0],6)
Prob_Sunken_neg = probability(X_train[X_train.cap_shape == 'Sunken'][X_train.category == 'Negative'].shape[0],X_train[y_train == 'Negative'].shape[0],6)

print(Prob_Sunken_pos)
print(Prob_Sunken_neg)
# Out:
# 0.007452574525745257
# 0.0010924981791697013
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# ...

# %%
#---------starting for feature 2 (cap_shape)
Prob_Fiberous_pos = probability(X_train[X_train.Cap_surface == 'Fiberous'][X_train.category == 'Positive'].shape[0],X_train[y_train == 'Positive'].shape[0],4)
Prob_Fiberous_neg = probability(X_train[X_train.Cap_surface == 'Fiberous'][X_train.category == 'Negative'].shape[0],X_train[y_train == 'Negative'].shape[0],4)


Prob_Smooth_pos = probability(X_train[X_train.Cap_surface == 'Smooth'][X_train.category == 'Positive'].shape[0],X_train[y_train == 'Positive'].shape[0],4)
Prob_Smooth_neg = probability(X_train[X_train.Cap_surface == 'Smooth'][X_train.category == 'Negative'].shape[0],X_train[y_train == 'Negative'].shape[0],4)


Prob_Scaly_pos = probability(X_train[X_train.Cap_surface == 'Scaly'][X_train.category == 'Positive'].shape[0],X_train[y_train == 'Positive'].shape[0],4)
Prob_Scaly_neg = probability(X_train[X_train.Cap_surface == 'Scaly'][X_train.category == 'Negative'].shape[0],X_train[y_train == 'Negative'].shape[0],4)

Prob_Grooves_pos = probability(X_train[X_train.Cap_surface == 'Grooves'][X_train.category == 'Positive'].shape[0],X_train[y_train == 'Positive'].shape[0],4)
Prob_Grooves_neg = probability(X_train[X_train.Cap_surface == 'Grooves'][X_train.category == 'Negative'].shape[0],X_train[y_train == 'Negative'].shape[0],4)



print(Prob_Fiberous_pos)
print(Prob_Fiberous_neg)
# Out:
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
#---------------for feature 3(bruises)
Prob_Bruises_pos = probability(X_train[X_train.bruises == 'Bruises'][X_train.category == 'Positive'].shape[0],X_train[y_train == 'Positive'].shape[0],2)
Prob_Bruises_neg = probability(X_train[X_train.bruises == 'Bruises'][X_train.category == 'Negative'].shape[0],X_train[y_train == 'Negative'].shape[0],2)


Prob_NoBruises_pos = probability(X_train[X_train.bruises == 'NoBruises'][X_train.category == 'Positive'].shape[0],X_train[y_train == 'Positive'].shape[0],2)
Prob_NoBruises_neg = probability(X_train[X_train.bruises == 'NoBruises'][X_train.category == 'Negative'].shape[0],X_train[y_train == 'Negative'].shape[0],2)

print(Prob_Bruises_pos)
# Out:
# 0.6478968792401628
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\alouk\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
X_train1 = X_test.to_numpy()#-------------x_train
X_train1 = np.delete(X_train1, np.s_[3], axis=1)

# %% [markdown]
# ## Predicting probability of combinations of instances

# %%
predicted = np.zeros((len(X_train1),1))
def prediction(a):
     ##----------testing
    for i in range(len(a)):
        if(X_train1[i][0] == 'Convex' and X_train1[i][1] == 'Scaly' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_convex_pos * Prob_Scaly_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_convex_neg * Prob_Scaly_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Bell' and X_train1[i][1] == 'Scaly' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Bell_pos * Prob_Scaly_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Bell_neg * Prob_Scaly_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Flat' and X_train1[i][1] == 'Scaly' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Flat_pos * Prob_Scaly_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Flat_neg * Prob_Scaly_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Knobbed' and X_train1[i][1] == 'Scaly' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Knobbed_pos * Prob_Scaly_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Knobbed_neg * Prob_Scaly_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Sunken' and X_train1[i][1] == 'Scaly' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Sunken_pos * Prob_Scaly_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Sunken_neg * Prob_Scaly_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Conical' and X_train1[i][1] == 'Scaly' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Conical_pos * Prob_Scaly_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Conical_neg * Prob_Scaly_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative




                #----cahnging fibrous



        if(X_train1[i][0] == 'Convex' and X_train1[i][1] == 'Fiberous' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_convex_pos * Prob_Fiberous_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_convex_neg * Prob_Fiberous_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Bell' and X_train1[i][1] == 'Fiberous' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Bell_pos * Prob_Fiberous_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Bell_neg * Prob_Fiberous_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Flat' and X_train1[i][1] == 'Fiberous' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Flat_pos * Prob_Fiberous_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Flat_neg * Prob_Fiberous_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Knobbed' and X_train1[i][1] == 'Fiberous' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Knobbed_pos * Prob_Fiberous_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Knobbed_neg * Prob_Fiberous_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Sunken' and X_train1[i][1] == 'Fiberous' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Sunken_pos * Prob_Fiberous_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Sunken_neg * Prob_Fiberous_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Conical' and X_train1[i][1] == 'Fiberous' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Conical_pos * Prob_Fiberous_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Conical_neg * Prob_Fiberous_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative








         #----cahnging smooth



        if(X_train1[i][0] == 'Convex' and X_train1[i][1] == 'Smooth' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_convex_pos * Prob_Smooth_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_convex_neg * Prob_Smooth_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Bell' and X_train1[i][1] == 'Smooth' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Bell_pos * Prob_Smooth_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Bell_neg * Prob_Smooth_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Flat' and X_train1[i][1] == 'Smooth' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Flat_pos * Prob_Smooth_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Flat_neg * Prob_Smooth_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Knobbed' and X_train1[i][1] == 'Smooth' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Knobbed_pos * Prob_Smooth_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Knobbed_neg * Prob_Smooth_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Sunken' and X_train1[i][1] == 'Smooth' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Sunken_pos * Prob_Smooth_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Sunken_neg * Prob_Smooth_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Conical' and X_train1[i][1] == 'Smooth' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Conical_pos * Prob_Smooth_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Conical_neg * Prob_Smooth_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative





        #----cahnging grooves



        if(X_train1[i][0] == 'Convex' and X_train1[i][1] == 'Grooves' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_convex_pos * Prob_Grooves_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_convex_neg * Prob_Grooves_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Bell' and X_train1[i][1] == 'Grooves' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Bell_pos * Prob_Grooves_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Bell_neg * Prob_Grooves_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Flat' and X_train1[i][1] == 'Grooves' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Flat_pos * Prob_Grooves_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Flat_neg * Prob_Grooves_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Knobbed' and X_train1[i][1] == 'Grooves' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Knobbed_pos * Prob_Grooves_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Knobbed_neg * Prob_Grooves_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Sunken' and X_train1[i][1] == 'Grooves' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Sunken_pos * Prob_Grooves_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Sunken_neg * Prob_Grooves_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Conical' and X_train1[i][1] == 'Grooves' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Conical_pos * Prob_Grooves_pos * Prob_NoBruises_pos
            negative_prob1 = Prob_Conical_neg * Prob_Grooves_neg * Prob_NoBruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


                #########
                #######
                #########
                ##########
                ##########
                ##########
                #############
                ###########3







        if(X_train1[i][0] == 'Convex' and X_train1[i][1] == 'Scaly' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_convex_pos * Prob_Scaly_pos * Prob_Bruises_pos
            negative_prob1 = Prob_convex_neg * Prob_Scaly_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Bell' and X_train1[i][1] == 'Scaly' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Bell_pos * Prob_Scaly_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Bell_neg * Prob_Scaly_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Flat' and X_train1[i][1] == 'Scaly' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Flat_pos * Prob_Scaly_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Flat_neg * Prob_Scaly_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Knobbed' and X_train1[i][1] == 'Scaly' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Knobbed_pos * Prob_Scaly_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Knobbed_neg * Prob_Scaly_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Sunken' and X_train1[i][1] == 'Scaly' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Sunken_pos * Prob_Scaly_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Sunken_neg * Prob_Scaly_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Conical' and X_train1[i][1] == 'Scaly' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Conical_pos * Prob_Scaly_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Conical_neg * Prob_Scaly_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative




                #----cahnging fibrous



        if(X_train1[i][0] == 'Convex' and X_train1[i][1] == 'Fiberous' and X_train1[i][2]== 'NoBruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_convex_pos * Prob_Fiberous_pos * Prob_Bruises_pos
            negative_prob1 = Prob_convex_neg * Prob_Fiberous_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Bell' and X_train1[i][1] == 'Fiberous' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Bell_pos * Prob_Fiberous_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Bell_neg * Prob_Fiberous_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Flat' and X_train1[i][1] == 'Fiberous' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Flat_pos * Prob_Fiberous_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Flat_neg * Prob_Fiberous_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Knobbed' and X_train1[i][1] == 'Fiberous' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Knobbed_pos * Prob_Fiberous_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Knobbed_neg * Prob_Fiberous_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Sunken' and X_train1[i][1] == 'Fiberous' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Sunken_pos * Prob_Fiberous_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Sunken_neg * Prob_Fiberous_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Conical' and X_train1[i][1] == 'Fiberous' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Conical_pos * Prob_Fiberous_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Conical_neg * Prob_Fiberous_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative








         #----cahnging smooth



        if(X_train1[i][0] == 'Convex' and X_train1[i][1] == 'Smooth' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_convex_pos * Prob_Smooth_pos * Prob_Bruises_pos
            negative_prob1 = Prob_convex_neg * Prob_Smooth_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Bell' and X_train1[i][1] == 'Smooth' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Bell_pos * Prob_Smooth_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Bell_neg * Prob_Smooth_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Flat' and X_train1[i][1] == 'Smooth' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Flat_pos * Prob_Smooth_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Flat_neg * Prob_Smooth_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Knobbed' and X_train1[i][1] == 'Smooth' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Knobbed_pos * Prob_Smooth_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Knobbed_neg * Prob_Smooth_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Sunken' and X_train1[i][1] == 'Smooth' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Sunken_pos * Prob_Smooth_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Sunken_neg * Prob_Smooth_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Conical' and X_train1[i][1] == 'Smooth' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Conical_pos * Prob_Smooth_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Conical_neg * Prob_Smooth_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative





        #----cahnging grooves



        if(X_train1[i][0] == 'Convex' and X_train1[i][1] == 'Grooves' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_convex_pos * Prob_Grooves_pos * Prob_Bruises_pos
            negative_prob1 = Prob_convex_neg * Prob_Grooves_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Bell' and X_train1[i][1] == 'Grooves' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Bell_pos * Prob_Grooves_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Bell_neg * Prob_Grooves_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Flat' and X_train1[i][1] == 'Grooves' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Flat_pos * Prob_Grooves_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Flat_neg * Prob_Grooves_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Knobbed' and X_train1[i][1] == 'Grooves' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Knobbed_pos * Prob_Grooves_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Knobbed_neg * Prob_Grooves_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

        if(X_train1[i][0] == 'Sunken' and X_train1[i][1] == 'Grooves' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Sunken_pos * Prob_Grooves_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Sunken_neg * Prob_Grooves_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative


        if(X_train1[i][0] == 'Conical' and X_train1[i][1] == 'Grooves' and X_train1[i][2]== 'Bruises'):
            positive_prob1 = 0
            negative_prob1 = 0
            positive_prob1 = Prob_Conical_pos * Prob_Grooves_pos * Prob_Bruises_pos
            negative_prob1 = Prob_Conical_neg * Prob_Grooves_neg * Prob_Bruises_neg
            if(positive_prob1 >= negative_prob1):
                predicted[i] = 1 #---positive
            else:
                predicted[i] = 0 #-----negative

# %%
predicted = np.zeros((len(X_test),1))##----------testing
prediction(X_test)#------------calling the main function


y_test_acc = y_test.replace({"Negative": 0, "Positive" : 1}, inplace = True)
y_test = y_test.to_numpy()

# %% [markdown]
# ## Finding Values for confusion matrix

# %%
L = []
for i in range(len(y_test)):
    if(y_test[i] == 1 and predicted[i] == 1):#------------TRUE POSITIVE VALUE
        L.append(y_test[i])
TP=len(L)    
print(TP)


L1 = []
for i in range(len(y_test)):
    if(y_test[i] == 0 and predicted[i] == 0):#------------FALSE POSITIVE VALUE
        L1.append(y_test[i])
FP=len(L1)    
print(FP)



L2 = []
for i in range(len(y_test)):
    if(y_test[i] != 1 and predicted[i] == 1):#------------TRUE NEGATIVE VALUE
        L2.append(y_test[i])
TN=len(L2)     
print(TN)


L3 = []
for i in range(len(y_test)):
    if(y_test[i] == 0 and predicted[i] != 0):#------------FALSE NEGATIVE VALUE
        L3.append(y_test[i])
FN=len(L2)     
print(FN)
# Out:
# 844
# 870
# 306
# 306

# %% [markdown]
# # The final Accuracy, Sensitivity and Specificity

# %%
accuracy(y_test,predicted)#---------------finding the accuracy
Sensitivity()
Specificity()
# Out:
# Accuracy is 70.30352748154225
# Sensitivity is 73.3913043478261
# Specificity is 26.02040816326531

# %%
predicted_values = pd.DataFrame({'Predicted': predicted[:, 0]})
predicted_values.replace({0.0: 'Negative', 1.0 : 'Positive'}, inplace = True)

# %% [markdown]
# ## Creating modified database which contains new coloumn "predicted_values"

# %%
X_test = X_test.assign(predicted_values=predicted_values.values)

# %%
X_test
# Out:
#      cap_shape Cap_surface    bruises  category predicted_values
# 3616    Convex    Fiberous  NoBruises  Negative         Positive
# 5386    Convex       Scaly  NoBruises  Positive         Negative
# 3760      Flat       Scaly    Bruises  Positive         Positive
# 4195      Flat    Fiberous    Bruises  Positive         Positive
# 2398    Convex       Scaly    Bruises  Positive         Positive
# ...        ...         ...        ...       ...              ...
# 5775    Convex      Smooth    Bruises  Negative         Positive
# 3926    Convex       Scaly  NoBruises  Negative         Negative
# 1393    Convex      Smooth  NoBruises  Positive         Negative
# 767       Flat    Fiberous  NoBruises  Positive         Negative
# 5778    Convex      Smooth    Bruises  Negative         Positive
#
# [2438 rows x 5 columns]

# %% [markdown]
# ## Exporting database to csv file

# %%
export_csv = X_test.to_csv (r'W:\Lakehead Study material\Big data\Assignment 2\Naive bayes\Work directory\predictions.csv', index = None, header=True)

# %%
accuracy(y_test,predicted)#---------------finding the accuracy
Sensitivity()
Specificity()
# Out:
# Accuracy is 70.30352748154225
# Sensitivity is 73.3913043478261
# Specificity is 26.02040816326531
